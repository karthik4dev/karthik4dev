# %% [markdown]
# #This is a new python Notebook

# %% [markdown]
# <h1> This is a New python Notebook <h1>/m

# %%
import math as m 
A=list(map(int,input().split()))
for i in range(len(A)):
    print(m.sqrt(A[i]), end=' ')
# Out:
# 2 3 4 5 6
# 1.4142135623730951 1.7320508075688772 2.0 2.23606797749979 2.449489742783178

# %% [markdown]
# #error
